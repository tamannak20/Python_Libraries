# %% [markdown]
# <p style = 'font-size:18px;color:green'> <b> -Tamanna </b> </p>

# %%
#import necessary library
import pandas as pd
import numpy as np

# %% [markdown]
# ## reading data

# %%
#load the data
df= pd.read_csv(r"C:\Users\taman\Downloads\archive (2)\Titanic.csv")

# %% [markdown]
# ## summary

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sex       891 non-null    object
#  1   age       714 non-null    float64
#  2   sibsp     891 non-null    int64
#  3   parch     891 non-null    int64
#  4   fare      891 non-null    float64
#  5   embarked  889 non-null    object
#  6   class     891 non-null    object
#  7   who       891 non-null    object
#  8   alone     891 non-null    bool
#  9   survived  891 non-null    int64
# dtypes: bool(1), float64(2), int64(3), object(4)
# memory usage: 63.6+ KB

# %%
#how large the dataframe
df.shape
# Out:
# (891, 10)

# %%
#statistics of the dataset
df.describe()
# Out:
#               age       sibsp       parch        fare    survived
# count  714.000000  891.000000  891.000000  891.000000  891.000000
# mean    29.699118    0.523008    0.381594   32.204208    0.383838
# std     14.526497    1.102743    0.806057   49.693429    0.486592
# min      0.420000    0.000000    0.000000    0.000000    0.000000
# 25%     20.125000    0.000000    0.000000    7.910400    0.000000
# 50%     28.000000    0.000000    0.000000   14.454200    0.000000
# 75%     38.000000    1.000000    0.000000   31.000000    1.000000
# max     80.000000    8.000000    6.000000  512.329200    1.000000

# %%
df["age"].describe()  #summary of a particular column
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
df["survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["survived"].mean()
# Out:
# 0.3838383838383838

# %%
#see first five rows
df.head()
# Out:
#       sex   age  sibsp  parch     fare embarked  class    who  alone  survived
# 0    male  22.0      1      0   7.2500        S  Third    man  False         0
# 1  female  38.0      1      0  71.2833        C  First  woman  False         1
# 2  female  26.0      0      0   7.9250        S  Third  woman   True         1
# 3  female  35.0      1      0  53.1000        S  First  woman  False         1
# 4    male  35.0      0      0   8.0500        S  Third    man   True         0

# %%
#see last five rows
df.tail()
# Out:
#         sex   age  sibsp  parch   fare embarked   class    who  alone  \
# 886    male  27.0      0      0  13.00        S  Second    man   True
# 887  female  19.0      0      0  30.00        S   First  woman   True
# 888  female   NaN      1      2  23.45        S   Third  woman  False
# 889    male  26.0      0      0  30.00        C   First    man   True
# 890    male  32.0      0      0   7.75        Q   Third    man   True
#
#      survived
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0

# %%
#show all the columns name
df.columns
# Out:
# Index(['sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who',
#        'alone', 'survived'],
#       dtype='object')

# %%
#Rows index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#values with their counts(in specific column)
df["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %% [markdown]
# ## dtypes

# %%
df.dtypes  #checking data type of df
# Out:
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# class        object
# who          object
# alone          bool
# survived      int64
# dtype: object

# %%
df.alone=df.alone.astype('float64')

# %%
df.dtypes
# Out:
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# class        object
# who          object
# alone       float64
# survived      int64
# dtype: object

# %% [markdown]
# ## Creating DataFrame                                           -----we use pd.DataFrame() constructor

# %%
#creating empty dataframe
Data_Frame=pd.DataFrame()
Data_Frame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#creating dataframe using dictionary
Student_dict={"Name":["Tamanna","Riya","Sheenu"],
                     "Age":[20,22,19],
                     "RollNo":[1,2,3]}
df_student=pd.DataFrame(Student_dict)   #converting into dataframe
df_student
# Out:
#       Name  Age  RollNo
# 0  Tamanna   20       1
# 1     Riya   22       2
# 2   Sheenu   19       3

# %%
pd.DataFrame({"Name":["Tina","siya"],
             "salary":['20k','30k']},
              index=["employe1","employe2"])   #list of row labels is called index
# Out:
#           Name salary
# employe1  Tina    20k
# employe2  siya    30k

# %% [markdown]
# ## Handeling missing values-----    isnull() , fillna()

# %%
df.isnull().sum()
# Out:
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# class         0
# who           0
# alone         0
# survived      0
# dtype: int64

# %%
#check on a particular columns
df["age"].isnull().sum()
# Out:
# 177

# %%
df["age"].fillna(df["age"].mean(),inplace=True)    #fill that missing value
df["age"].isnull().sum()    #recheck is there any missing value in "age" column
# Out:
# 0

# %% [markdown]
# ## Converting a categorical feature

# %%
df["sex"]=df["sex"].map({"male":"0","female":"1"}).astype(int)
df.head()
# Out:
#    sex   age  sibsp  parch     fare embarked  class    who  alone  survived
# 0    0  22.0      1      0   7.2500        S  Third    man    0.0         0
# 1    1  38.0      1      0  71.2833        C  First  woman    0.0         1
# 2    1  26.0      0      0   7.9250        S  Third  woman    1.0         1
# 3    1  35.0      1      0  53.1000        S  First  woman    0.0         1
# 4    0  35.0      0      0   8.0500        S  Third    man    1.0         0

# %% [markdown]
# # Slicing DataFrame
# ## (loc- label-based indexing , iloc- integer-based indexing)

# %%
df["fare"][2]  #fetching 2row in 'fare' column
# Out:
# 7.925

# %%
df.iloc[1,4]   #1st row and 4th column
# Out:
# 71.2833

# %%
df.iloc[:2]   #all columns and two rows
# Out:
#    sex   age  sibsp  parch     fare embarked  class    who  alone  survived
# 0    0  22.0      1      0   7.2500        S  Third    man    0.0         0
# 1    1  38.0      1      0  71.2833        C  First  woman    0.0         1

# %%
df.iloc[3:5,]  #3 and 4 row also all columns
# Out:
#    sex   age  sibsp  parch   fare embarked  class    who  alone  survived
# 3    1  35.0      1      0  53.10        S  First  woman    0.0         1
# 4    0  35.0      0      0   8.05        S  Third    man    1.0         0

# %%
df.iloc[-6:]   #last 6 rows ,all columns
# Out:
#      sex        age  sibsp  parch    fare embarked   class    who  alone  \
# 885    1  39.000000      0      5  29.125        Q   Third  woman    0.0
# 886    0  27.000000      0      0  13.000        S  Second    man    1.0
# 887    1  19.000000      0      0  30.000        S   First  woman    1.0
# 888    1  29.699118      1      2  23.450        S   Third  woman    0.0
# 889    0  26.000000      0      0  30.000        C   First    man    1.0
# 890    0  32.000000      0      0   7.750        Q   Third    man    1.0
#
#      survived
# 885         0
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0

# %%
df.iloc[-3:,6]   #last 3 rows , 6th column
# Out:
# 888    Third
# 889    First
# 890    Third
# Name: class, dtype: object

# %%
df.loc[1,'alone']   #1st row and 'alone' column
# Out:
# 0.0

# %%
df.loc[2:4,"parch"]   #2,3,4 row , 'parch' column
# Out:
# 2    0
# 3    0
# 4    0
# Name: parch, dtype: int64

# %%
df.loc[:,["sex","age","survived"]]  #all rows and 'sex','age','survived' columns
# Out:
#      sex        age  survived
# 0      0  22.000000         0
# 1      1  38.000000         1
# 2      1  26.000000         1
# 3      1  35.000000         1
# 4      0  35.000000         0
# ..   ...        ...       ...
# 886    0  27.000000         0
# 887    1  19.000000         1
# 888    1  29.699118         0
# 889    0  26.000000         1
# 890    0  32.000000         0
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Manipulating the index------set_index , reset_index

# %%
df.set_index(["age"],inplace=True)     #assigns the result back to the DataFrame 'df' using the inplace=True

# %%
df
# Out:
#            sex  sibsp  parch     fare embarked   class    who  alone  survived
# age
# 22.000000    0      1      0   7.2500        S   Third    man    0.0         0
# 38.000000    1      1      0  71.2833        C   First  woman    0.0         1
# 26.000000    1      0      0   7.9250        S   Third  woman    1.0         1
# 35.000000    1      1      0  53.1000        S   First  woman    0.0         1
# 35.000000    0      0      0   8.0500        S   Third    man    1.0         0
# ...        ...    ...    ...      ...      ...     ...    ...    ...       ...
# 27.000000    0      0      0  13.0000        S  Second    man    1.0         0
# 19.000000    1      0      0  30.0000        S   First  woman    1.0         1
# 29.699118    1      1      2  23.4500        S   Third  woman    0.0         0
# 26.000000    0      0      0  30.0000        C   First    man    1.0         1
# 32.000000    0      0      0   7.7500        Q   Third    man    1.0         0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#            age  sex  sibsp  parch     fare embarked   class    who  alone  \
# 0    22.000000    0      1      0   7.2500        S   Third    man    0.0
# 1    38.000000    1      1      0  71.2833        C   First  woman    0.0
# 2    26.000000    1      0      0   7.9250        S   Third  woman    1.0
# 3    35.000000    1      1      0  53.1000        S   First  woman    0.0
# 4    35.000000    0      0      0   8.0500        S   Third    man    1.0
# ..         ...  ...    ...    ...      ...      ...     ...    ...    ...
# 886  27.000000    0      0      0  13.0000        S  Second    man    1.0
# 887  19.000000    1      0      0  30.0000        S   First  woman    1.0
# 888  29.699118    1      1      2  23.4500        S   Third  woman    0.0
# 889  26.000000    0      0      0  30.0000        C   First    man    1.0
# 890  32.000000    0      0      0   7.7500        Q   Third    man    1.0
#
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# ...

# %% [markdown]
# ## Deleting columns-------     drop()

# %%
df.drop(['parch'],axis=1)    #drop that column     for column axis=1, for row axis=0
# Out:
#            age  sex  sibsp     fare embarked   class    who  alone  survived
# 0    22.000000    0      1   7.2500        S   Third    man    0.0         0
# 1    38.000000    1      1  71.2833        C   First  woman    0.0         1
# 2    26.000000    1      0   7.9250        S   Third  woman    1.0         1
# 3    35.000000    1      1  53.1000        S   First  woman    0.0         1
# 4    35.000000    0      0   8.0500        S   Third    man    1.0         0
# ..         ...  ...    ...      ...      ...     ...    ...    ...       ...
# 886  27.000000    0      0  13.0000        S  Second    man    1.0         0
# 887  19.000000    1      0  30.0000        S   First  woman    1.0         1
# 888  29.699118    1      1  23.4500        S   Third  woman    0.0         0
# 889  26.000000    0      0  30.0000        C   First    man    1.0         1
# 890  32.000000    0      0   7.7500        Q   Third    man    1.0         0
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Renaming the columns------rename()

# %%
df=df.rename(columns={"sex":"gender"})   #updating column names

# %%
df
# Out:
#            age  gender  sibsp  parch     fare embarked   class    who  alone  \
# 0    22.000000       0      1      0   7.2500        S   Third    man    0.0
# 1    38.000000       1      1      0  71.2833        C   First  woman    0.0
# 2    26.000000       1      0      0   7.9250        S   Third  woman    1.0
# 3    35.000000       1      1      0  53.1000        S   First  woman    0.0
# 4    35.000000       0      0      0   8.0500        S   Third    man    1.0
# ..         ...     ...    ...    ...      ...      ...     ...    ...    ...
# 886  27.000000       0      0      0  13.0000        S  Second    man    1.0
# 887  19.000000       1      0      0  30.0000        S   First  woman    1.0
# 888  29.699118       1      1      2  23.4500        S   Third  woman    0.0
# 889  26.000000       0      0      0  30.0000        C   First    man    1.0
# 890  32.000000       0      0      0   7.7500        Q   Third    man    1.0
#
#      survived
# 0           0
# ...

# %% [markdown]
# ## sorting-----sort_values()

# %%
df=df.sort_values(by="survived")

# %%
df
# Out:
#            age  gender  sibsp  parch      fare embarked   class    who  alone  \
# 0    22.000000       0      1      0    7.2500        S   Third    man    0.0
# 519  32.000000       0      0      0    7.8958        S   Third    man    1.0
# 521  22.000000       0      0      0    7.8958        S   Third    man    1.0
# 522  29.699118       0      0      0    7.2250        C   Third    man    1.0
# 524  29.699118       0      0      0    7.2292        C   Third    man    1.0
# ..         ...     ...    ...    ...       ...      ...     ...    ...    ...
# 546  19.000000       1      1      0   26.0000        S  Second  woman    0.0
# 215  31.000000       1      1      0  113.2750        C   First  woman    0.0
# 216  27.000000       1      0      0    7.9250        S   Third  woman    1.0
# 218  32.000000       1      0      0   76.2917        C   First  woman    1.0
# 445   4.000000       0      0      2   81.8583        S   First  child    0.0
#
#      survived
# 0           0
# ...

# %%
df=df.sort_values(by="sibsp",ascending=True)    # defaults to an ascending sort, where the lowest values comes first

# %%
df
# Out:
#            age  gender  sibsp  parch     fare embarked   class    who  alone  \
# 196  29.699118       0      0      0   7.7500        Q   Third    man    1.0
# 321  27.000000       0      0      0   7.8958        S   Third    man    1.0
# 14   14.000000       1      0      0   7.8542        S   Third  child    1.0
# 285  33.000000       0      0      0   8.6625        C   Third    man    1.0
# 277  29.699118       0      0      0   0.0000        S  Second    man    1.0
# ..         ...     ...    ...    ...      ...      ...     ...    ...    ...
# 159  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 846  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 324  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 201  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 180  29.699118       1      8      2  69.5500        S   Third  woman    0.0
#
#      survived
# 196         0
# ...

# %%
df=df.sort_values(by="sibsp",ascending=False)    #if we want descending sort just do ascending=False

# %%
df
# Out:
#            age  gender  sibsp  parch     fare embarked   class    who  alone  \
# 180  29.699118       1      8      2  69.5500        S   Third  woman    0.0
# 201  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 324  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 846  29.699118       0      8      2  69.5500        S   Third    man    0.0
# 159  29.699118       0      8      2  69.5500        S   Third    man    0.0
# ..         ...     ...    ...    ...      ...      ...     ...    ...    ...
# 796  49.000000       1      0      0  25.9292        S   First  woman    1.0
# 740  29.699118       0      0      0  30.0000        S   First    man    1.0
# 828  29.699118       0      0      0   7.7500        Q   Third    man    1.0
# 673  31.000000       0      0      0  13.0000        S  Second    man    1.0
# 411  29.699118       0      0      0   6.8583        Q   Third    man    1.0
#
#      survived
# 180         0
# ...

# %%
df["age"].mean()
# Out:
# 29.69911764705876

# %% [markdown]
# ## groupby

# %%
df1=df.groupby(["class"])["fare"].sum()
df1
# Out:
# class
# First     18177.4125
# Second     3801.8417
# Third      6714.6951
# Name: fare, dtype: float64

# %% [markdown]
# ## adding rows -----append()

# %%
row=dict({"age":24,"gender":1})
df=df.append(row,ignore_index=True)
df

# %%
df=df.drop(df.index[-1],axis=0)

# %%
df  #892th row deleted

# %% [markdown]
# ## combining two dataset-----concat()

# %%
df_1=pd.read_csv(r"C:\Users\taman\Downloads\archive (2)\Titanic.csv")
df_2=pd.read_csv(r"C:\Users\taman\Downloads\Automobile_data.csv")
DF= pd.concat([df_1,df_2])
DF

# %% [markdown]
# ## filtering

# %%
data=(df["gender"]==1)&(df["fare"]>60.0000)    #having gender is equal to 1 and fare greater than 65.0000  
data

# %%
data1=(df["age"]==31)|(df["alone"]<1.0)      #having age is equal to 31 or alone less than 1.0 
data1
